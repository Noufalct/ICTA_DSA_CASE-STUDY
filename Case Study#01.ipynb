# %% [markdown]
# # 1 Read the dataset to the python environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('E:/Python programming/WK#3/cars_data.csv')

# %%
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %%
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %% [markdown]
# # 2 Check for the null values present in the dataset.

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3 Plot a bar graph of male vs female buyers participated in the sales.

# %%
s = sns.countplot(x="Buyer Gender", hue=None, data=data)

# %% [markdown]
# # 4 Find the top 5 cars based on their sales price.

# %%
data1=data.sort_values(by='Sale Price',ascending=False).head(5)

# %%
data1.style.set_properties(**{'background-color':'Yellow'}, subset=['Make','Model','Sale Price'])
# Out:
# <style type="text/css">
# #T_7a37d_row0_col0, #T_7a37d_row0_col1, #T_7a37d_row0_col14, #T_7a37d_row1_col0, #T_7a37d_row1_col1, #T_7a37d_row1_col14, #T_7a37d_row2_col0, #T_7a37d_row2_col1, #T_7a37d_row2_col14, #T_7a37d_row3_col0, #T_7a37d_row3_col1, #T_7a37d_row3_col14, #T_7a37d_row4_col0, #T_7a37d_row4_col1, #T_7a37d_row4_col14 {
#   background-color: Yellow;
# }
# </style>
# <table id="T_7a37d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Make</th>
#       <th class="col_heading level0 col1" >Model</th>
#       <th class="col_heading level0 col2" >Nickname</th>
#       <th class="col_heading level0 col3" >Car Gender</th>
#       <th class="col_heading level0 col4" >Buyer Gender</th>
#       <th class="col_heading level0 col5" >Buyer Age</th>
#       <th class="col_heading level0 col6" >Buzzword</th>
#       <th class="col_heading level0 col7" >Country</th>
#       <th class="col_heading level0 col8" >City</th>
# ...

# %% [markdown]
# # 5 Find the least 5 cars based on their Resell price.

# %%
data2=data.sort_values("Resell Price").head(5)

# %%
data2.style.set_properties(**{'background-color': 'Green'}, subset=['Make','Model','Resell Price'])
# Out:
# <style type="text/css">
# #T_7599e_row0_col0, #T_7599e_row0_col1, #T_7599e_row0_col16, #T_7599e_row1_col0, #T_7599e_row1_col1, #T_7599e_row1_col16, #T_7599e_row2_col0, #T_7599e_row2_col1, #T_7599e_row2_col16, #T_7599e_row3_col0, #T_7599e_row3_col1, #T_7599e_row3_col16, #T_7599e_row4_col0, #T_7599e_row4_col1, #T_7599e_row4_col16 {
#   background-color: Green;
# }
# </style>
# <table id="T_7599e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Make</th>
#       <th class="col_heading level0 col1" >Model</th>
#       <th class="col_heading level0 col2" >Nickname</th>
#       <th class="col_heading level0 col3" >Car Gender</th>
#       <th class="col_heading level0 col4" >Buyer Gender</th>
#       <th class="col_heading level0 col5" >Buyer Age</th>
#       <th class="col_heading level0 col6" >Buzzword</th>
#       <th class="col_heading level0 col7" >Country</th>
#       <th class="col_heading level0 col8" >City</th>
# ...
